# %% [markdown]
# <a href="https://colab.research.google.com/github/CPernet/Semantically_Incongruent_or_Congruent_Eggplants_revised/blob/main/python/full_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis of the stimuli from [Toffolo et al. (2022)](https://pmc.ncbi.nlm.nih.gov/articles/PMC9540983/)
#
# The Event Related Potentials (ERP) can reveal 3 effects of interest:
# - Recognition potential (RP ~200ms, parietal-occipital scalp regions) which is typically stronger for congruent words and may reflect lexical processing. This analysis of stimuli will therefore extract lexical information (e.g. frequency)
# - PN400, the main ERP component from the original paper. This ERP shows increased amplitude with incongruency leading to considered N400 as an index of semantic integration. Information such as close probability, semantic deviation, syntactic deviation (distance measures) can differentiate those effects.
# - late positivity component (LPC ~600ms) that shows increased amplitude with incongruency and related to both syntactic information and to semantic difficulty
#
# This notebook compute various metrics from the sentences and last word in order the perform a regression based analysis of ERP data.

# %% [markdown]
# Clone the GitHub repository in which stimuli details are stored

# %%
# !git clone https://github.com/CPernet/Semantically_Incongruent_or_Congruent_Eggplants_revised.git
# Out:
# fatal: destination path 'Semantically_Incongruent_or_Congruent_Eggplants_revised' already exists and is not an empty directory.

# %%
# %cd Semantically_Incongruent_or_Congruent_Eggplants_revised
# Out:
# /content/Semantically_Incongruent_or_Congruent_Eggplants_revised

# %%
# %cd /content/Semantically_Incongruent_or_Congruent_Eggplants_revised
# Out:
# /content/Semantically_Incongruent_or_Congruent_Eggplants_revised

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/ERP_DATA/erps_only_.mat.zip" -d erps
# Out:
# Archive:  /content/drive/MyDrive/ERP_DATA/erps_only_.mat.zip
#    creating: erps/erps_only_.mat/
#   inflating: erps/erps_only_.mat/N400Stimset_stimuli_parameters.tsv
#    creating: erps/erps_only_.mat/sub-01/
#   inflating: erps/erps_only_.mat/sub-01/sub-01_task-N400Stimset_channels.tsv
#   inflating: erps/erps_only_.mat/sub-01/sub-01_task-N400Stimset_erp-CP.mat
#   inflating: erps/erps_only_.mat/sub-01/sub-01_task-N400Stimset_erp-GA.mat
#   inflating: erps/erps_only_.mat/sub-01/sub-01_task-N400Stimset_erp-LD.mat
#   inflating: erps/erps_only_.mat/sub-01/sub-01_task-N400Stimset_erp-Order.mat
#   inflating: erps/erps_only_.mat/sub-01/sub-01_task-N400Stimset_erp-Time.mat
#    creating: erps/erps_only_.mat/sub-02/
#   inflating: erps/erps_only_.mat/sub-02/sub-02_task-N400Stimset_channels.tsv
#   inflating: erps/erps_only_.mat/sub-02/sub-02_task-N400Stimset_erp-CP.mat
#   inflating: erps/erps_only_.mat/sub-02/sub-02_task-N400Stimset_erp-GA.mat
# ...

# %%
# %cd /content/Semantically_Incongruent_or_Congruent_Eggplants_revised
# Out:
# /content/Semantically_Incongruent_or_Congruent_Eggplants_revised

# %%
# !pip install -r Cyril_Angela_language/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 152.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 106.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.7/939.7 kB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.1/183.1 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 122.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.26.1
#     Uninstalling wandb-0.26.1:
#       Successfully uninstalled wandb-0.26.1
# ...

# %%
# !python Cyril_Angela_language/export_erp_long.py ./erps/erps_only_.mat --bids-root ./erps/erps_only_.mat && mv eeg_outputs /content/drive/MyDrive/ERP_DATA/
# Out:
# Found 20 ERP CP files.
# Using BIDS root: erps/erps_only_.mat
# Using electrodes file: erps/erps_only_.mat/task-N400Stimset_electrodes.tsv
#
# Processing sub-01_task-N400Stimset_erp-CP.mat
#   Condition 1: 29 trials x 615 timepoints x 128 channels
#   Condition 2: 40 trials x 615 timepoints x 128 channels
#   Condition 3: 30 trials x 615 timepoints x 128 channels
#   Condition 4: 26 trials x 615 timepoints x 128 channels
#   Condition 5: 33 trials x 615 timepoints x 128 channels
#   Condition 6: 31 trials x 615 timepoints x 128 channels
#   Condition 7: 25 trials x 615 timepoints x 128 channels
#   Condition 8: 23 trials x 615 timepoints x 128 channels
# Saved: eeg_outputs/sub-01_erp_long.csv
#
# Processing sub-02_task-N400Stimset_erp-CP.mat
#   Condition 1: 51 trials x 615 timepoints x 128 channels
#   Condition 2: 50 trials x 615 timepoints x 128 channels
#   Condition 3: 44 trials x 615 timepoints x 128 channels
#   Condition 4: 40 trials x 615 timepoints x 128 channels
# ...

# %%
# !python Cyril_Angela_language/run_component_lmm.py --erp-long /content/drive/MyDrive/ERP_DATA/eeg_outputs/ALL_erp_long.csv --predictors /content/Semantically_Incongruent_or_Congruent_Eggplants_revised/language_outputs/ALL_language_metrics.csv --component ALL --output-dir /content/drive/MyDrive/LMM_OUTPUTS
# Out:
# ...
# Running component model: RP
# ...
# 15:21:32  INFO  Computing RP average from /content/drive/MyDrive/ERP_DATA/eeg_outputs/ALL_erp_long.csv
# 15:21:35  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:36  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:38  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:40  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:42  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:44  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:45  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:47  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:48  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:50  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:50  INFO  Processed 10 ERP chunks
# 15:21:52  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:53  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# 15:21:55  INFO  RP: using named ROI channels: ['Oz', 'Pz']
# ...

# %%
# !pip install "numpy<2"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 101.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !rm -rf /content/drive/MyDrive/EEG_OUTPUTS/eeg_outputs

# %%
# !python Cyril_Angela_language/export_erp_long.py ./erps/erps_only_.mat --bids-root ./erps/erps_only_.mat --output-dir /content/drive/MyDrive/EEG_OUTPUTS/eeg_outputs
# Out:
# Found 20 ERP CP files.
# Using BIDS root: erps/erps_only_.mat
# Using electrodes file: erps/erps_only_.mat/task-N400Stimset_electrodes.tsv
#
# Processing sub-01_task-N400Stimset_erp-CP.mat
#   Condition 1: 29 trials x 615 timepoints x 128 channels
#   Condition 2: 40 trials x 615 timepoints x 128 channels
#   Condition 3: 30 trials x 615 timepoints x 128 channels
#   Condition 4: 26 trials x 615 timepoints x 128 channels
#   Condition 5: 33 trials x 615 timepoints x 128 channels
#   Condition 6: 31 trials x 615 timepoints x 128 channels
#   Condition 7: 25 trials x 615 timepoints x 128 channels
#   Condition 8: 23 trials x 615 timepoints x 128 channels
# Saved: /content/drive/MyDrive/EEG_OUTPUTS/eeg_outputs/sub-01_erp_long.csv
#
# Processing sub-02_task-N400Stimset_erp-CP.mat
#   Condition 1: 51 trials x 615 timepoints x 128 channels
#   Condition 2: 50 trials x 615 timepoints x 128 channels
#   Condition 3: 44 trials x 615 timepoints x 128 channels
# ...

# %%
# !unzip Cyril_Angela_language/language_outputs.zip
# Out:
# Archive:  Cyril_Angela_language/language_outputs.zip
#    creating: language_outputs/
#   inflating: language_outputs/N400Stimset_cloze-probability-survey_results_predictor_diagnostics_vif.csv
#   inflating: language_outputs/N400Stimset_stimuli_parameters_predictor_diagnostics_vif.csv
#   inflating: language_outputs/ALL_language_metrics.csv
#   inflating: language_outputs/N400Stimset_stimuli_parameters_language_metrics.csv
#   inflating: language_outputs/ALL_predictor_diagnostics_correlations.csv
#   inflating: language_outputs/N400Stimset_stimuli_parameters_predictor_diagnostics_correlations.csv
#   inflating: language_outputs/ALL_predictor_diagnostics_vif.csv
#   inflating: language_outputs/N400Stimset_cloze-probability-survey_results_language_metrics.csv
#   inflating: language_outputs/N400Stimset_cloze-probability-survey_results_predictor_diagnostics_correlations.csv

# %%
# !python Cyril_Angela_language/export_erp_long.py ./erps/erps_only_.mat --bids-root ./erps/erps_only_.mat
# Out:
# Found 20 ERP CP files.
# Using BIDS root: erps/erps_only_.mat
# Using electrodes file: erps/erps_only_.mat/task-N400Stimset_electrodes.tsv
#
# Processing sub-01_task-N400Stimset_erp-CP.mat
#   Condition 1: 29 trials x 615 timepoints x 128 channels
#   Condition 2: 40 trials x 615 timepoints x 128 channels
#   Condition 3: 30 trials x 615 timepoints x 128 channels
#   Condition 4: 26 trials x 615 timepoints x 128 channels
#   Condition 5: 33 trials x 615 timepoints x 128 channels
#   Condition 6: 31 trials x 615 timepoints x 128 channels
#   Condition 7: 25 trials x 615 timepoints x 128 channels
#   Condition 8: 23 trials x 615 timepoints x 128 channels
# Saved: eeg_outputs/sub-01_erp_long.csv
#
# Processing sub-02_task-N400Stimset_erp-CP.mat
#   Condition 1: 51 trials x 615 timepoints x 128 channels
#   Condition 2: 50 trials x 615 timepoints x 128 channels
#   Condition 3: 44 trials x 615 timepoints x 128 channels
#   Condition 4: 40 trials x 615 timepoints x 128 channels
# ...

# %%
# !find ./erps/erps_only_.mat -maxdepth 3 -type f | head -50

# %%
# !pwd

# %%
# !zip -r eeg_outputs.zip eeg_outputs

# %%
from google.colab import files
files.download("eeg_outputs.zip")

# %%
# !pip install -r Cyril_Angela_language/requirements.txt

# %%
# !python Cyril_Angela_language/process_stimuli.py stimuli/

# %%
# !zip -r language_outputs.zip language_outputs

# %%
from google.colab import files
files.download("language_outputs.zip")

# %%
# !unzip stimuli.zip

# %%
# !unzip stimuli.zip

# %% [markdown]
# ```markdown
# ## Setup and Data Acquisition
# First, we clone the repository and install the necessary Python dependencies.
# ```

# %%
# %cd stimuli/

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !unzip stimuli.zip

# %%
# %cd ..

# %%
# !python Cyril_Angela_language/process_stimuli.py stimuli/

# %%
# !zip -r language_outputs.zip language_outputs

# %%
from google.colab import files
files.download("language_outputs.zip")

# %%
import os
# Remove old clone if it exists to ensure a fresh start
# !rm -rf Semantically_Incongruent_or_Congruent_Eggplants_revised

# Clone the updated repository
# !git clone https://github.com/CPernet/Semantically_Incongruent_or_Congruent_Eggplants_revised.git

# Install dependencies from the python folder
# %cd Semantically_Incongruent_or_Congruent_Eggplants_revised/python
# !pip install -r requirements.txt
# %cd ../..

# %% [markdown]
# ```markdown
# Next, we check the stimuli folder and unzip it. Note: We use a manual download and pushed to GitHub, Dryad API did not work for automated request.
# ```

# %%
import os
import zipfile

base_dir = 'Semantically_Incongruent_or_Congruent_Eggplants_revised'
stimuli_path = os.path.join(base_dir, 'stimuli')
dataset_path = 'dataset'
os.makedirs(dataset_path, exist_ok=True)

if not os.path.exists(stimuli_path):
    print(f'Error: {stimuli_path} not found. Listing current directory:')
    # !ls -R {base_dir}
else:
    files = [f for f in os.listdir(stimuli_path) if f.endswith('.zip')]
    print(f'Found {len(files)} zip files in {stimuli_path}')
    for file in files:
        file_path = os.path.join(stimuli_path, file)
        print(f'Extracting {file}...')
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(dataset_path)

    print(f'\nExtraction complete. Files in {dataset_path}:')
    print(os.listdir(dataset_path))

# %%
import os
import zipfile

dataset_path = 'dataset'
nested_zip = os.path.join(dataset_path, 'stimuli.zip')

if os.path.exists(nested_zip):
    print(f"Extracting nested archive: {nested_zip}...")
    with zipfile.ZipFile(nested_zip, 'r') as zip_ref:
        zip_ref.extractall(dataset_path)
    print("Extraction of nested stimuli complete.")
else:
    print("No nested stimuli.zip found.")

# Final verification of files
files = os.listdir(dataset_path)
print(f"\nFinal files in '{dataset_path}':")
for f in sorted(files):
    print(f" - {f}")

# %%
import pandas as pd
import json

# Load TSV structure - this part usually works fine
tsv_path = 'dataset/N400Stimset_cloze-probability-survey_results.tsv'
df_tsv = pd.read_csv(tsv_path, sep='\t')

# Peek at the JSON file to diagnose the JSONDecodeError
json_path = 'dataset/N400Stimset_cloze-probability-survey_results.json'
print("--- JSON File Preview (First 5 lines) ---")
with open(json_path, 'r') as f:
    for _ in range(5):
        print(f.readline().strip())

print("\n--- TSV Columns ---")
print(df_tsv.columns.tolist())

display(df_tsv.head())

# %%
import os

# Fix the script to use tab separator for the input file
script_path = 'Semantically_Incongruent_or_Congruent_Eggplants_revised/python/process_stimuli.py'
with open(script_path, 'r') as f:
    content = f.read()

# Replace the standard read_csv call with one that uses sep='\t'
fixed_content = content.replace("df = pd.read_csv(args.input)", "df = pd.read_csv(args.input, sep='\\t')")

with open(script_path, 'w') as f:
    f.write(fixed_content)

# Inspect line 172 of the parameters file to check for anomalies
params_file = 'dataset/N400Stimset_stimuli_parameters.tsv'
print(f"--- Inspecting {params_file} near line 172 ---")
with open(params_file, 'r') as f:
    lines = f.readlines()
    for i in range(170, 175):
        if i < len(lines):
            print(f"Line {i+1}: {repr(lines[i])}")

# Attempt to run the script again
print("\n--- Running the fixed script ---")
# %cd Semantically_Incongruent_or_Congruent_Eggplants_revised/python
# !python process_stimuli.py ../../dataset/N400Stimset_stimuli_parameters.tsv
# %cd ../..

# %%
# %cd ..

# %%
# !rm -rf Semantically_Incongruent_or_Congruent_Eggplants_revised

# %%
# !git clone https://github.com/CPernet/Semantically_Incongruent_or_Congruent_Eggplants_revised.git

# %%
# %cd Semantically_Incongruent_or_Congruent_Eggplants_revised/

# %%
# !unzip stimuli/stimuli.zip

# %%
# !pwd

# %%
# !python Cyril_Angela_language/process_stimuli.py stimuli/

# %%
# !grep -n "allowed_names" -A10 Cyril_Angela_language/process_stimuli.py

# %%
# !grep -n "def should_skip_file" -A40 Cyril_Angela_language/process_stimuli.py

# %%
# %cd content/

# %%
# !rm -rf Semantically_Incongruent_or_Congruent_Eggplants_revised

# %%
# !git clone https://github.com/CPernet/Semantically_Incongruent_or_Congruent_Eggplants_revised.git

# %%
# %cd Semantically_Incongruent_or_Congruent_Eggplants_revised

# %%
# !unzip stimuli/stimuli.zip

# %%
# !pip install -r Cyril_Angela_language/requirements.txt

# %%
# !python Cyril_Angela_language/process_stimuli.py stimuli/

# %%
# %cd stimuli/

# %%
# !find stimuli -name "*.tsv"

# %%
# %cd ..

# %%
# !python Cyril_Angela_language/process_stimuli.py stimuli/

# %%
# !ls

# %%
# !unzip stimuli.zip -d stimuli

# %%
# %cd ..

# %%
# !zip -r language_outputs.zip language_outputs

# %%
from google.colab import files
files.download("language_outputs.zip")
